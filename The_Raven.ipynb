# %% [markdown]
# <a href="https://colab.research.google.com/github/APrater84/Classwork/blob/main/The_Raven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Elasticsearch
# Out:
# ...
#      |████████████████████████████████| 378 kB 4.9 MB/s
# ...

# %%
# !pip install requests

# %%
# !pip install lxml

# %%
# !pip install bleach

# %%
import collections
from urllib.parse import urljoin

# %%
import requests
from lxml import html
import bleach

# %%
STARTING_URL = 'https://www.poetryfoundation.org/poems/48860/the-raven'

# %%
urls_queue = collections.deque()
urls_queue.append(STARTING_URL)
found_urls = set()
found_urls.add(STARTING_URL)

# %%
while len(urls_queue):
    url = urls_queue.popleft()

    response = requests.get(url)
    parsed_body = html.fromstring(response.content)
    # print(parsed_body)
    html_content = response.text
    text_only = bleach.clean(html_content, strip=True)
    print(text_only)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         (function(d) {
#             var config = {
#                 kitId: 'lhu6lte',
#                 scriptTimeout: 3000,
#                 async: true
#             },
#             h=d.documentElement,
#             t=setTimeout(function(){
#                 h.className=h.className.replace(/\bwf-loading\b/g,"")+" wf-inactive";
#             },
#             config.scriptTimeout),
#             tk=d.createElement("script"),
#             f=false,
#             s=d.getElementsByTagName("script")[0],
#             a;
#             h.className+=" wf-loading";
#             tk.src='https://use.typekit.net/'+config.kitId+'.js';
#             tk.async=true;
#             tk.onload=tk.onreadystatechange=function(){
# ...

# %%
    links = {urljoin(response.url, url) for url in parsed_body.xpath('//a/@href') if
             urljoin(response.url, url).startswith('http')}

# %%
 for link in (links - found_urls):
        found_urls.add(link)
        urls_queue.append(link)
